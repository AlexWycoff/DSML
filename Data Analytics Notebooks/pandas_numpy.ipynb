# %% [markdown]
# # Pandas and Numpy
#
# These libraries are the foundation of what we'll be doing for the rest of the year. Dataframes are incredibly useful for data analysis (you can get summary info in one line, of many things), and numpy will be very nice to know once we get into machine learning

# %% [markdown]
# These kinds of cells are called markdown cells. They just contain neatly formatted text and won't execute as code when you run your notebook file. You can turn a cell into a markdown cell with a dropdown in Jupyter and you can use # to create titles with them

# %% [markdown]
# Markdown cells are pretty nice for commentary/analysis, you'll use them the most when explaining your process (or methodology).

# %%
import pandas as pd
import numpy as np

# Comments can also be useful for explaining things, but they're best used for documentation 
# (so don't use them like this)

# %% [markdown]
# These import statements just assign a "nickname" to the libraries so we can reference them more easily. They are personal preference but be warned: doing anything other than what I have here will offend data scientists.

# %% [markdown]
# Anyways, let's start by creating a dataframe. You can make one yourself or import from a .csv file

# %%
# Create a new, empty dataframe
df = pd.DataFrame()
# df is a common, albeit nondescript, dataframe name. Feel free to make your names more descriptive
display(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Wow it's empty that's crazy. The display command is something Jupyter has that can render the dataframes nicely

# %%
# Now we'll make a dataframe from a .csv file.

# Don't worry about this code right now, you won't need to use this
from pathlib import Path
path = Path(globals()['_dh'][0]).parent/"Data/Concussion Injuries 2012-2014.csv"

# Notice the descriptive name that is not df. This makes your code legible
sports_injuries = pd.read_csv(path)

# the path variable here should be replaced with r"path/to/file.csv"
# where "path/to/file.csv" is the absolute path, it looks something like:
# /Users/alexanderwycoff/Documents/notebooks/DSML/Data/Concussion Injuries 2012-2014.csv
# I don't use this because absolute paths will not work if someone clones the github repo

# %% [markdown]
# Now let's actually use the display command on a non-empty dataframe:

# %%
display(sports_injuries)
# Out:
#                                                     ID             Player  \
# 0    Aldrick Robinson - Washington Redskins vs. Tam...   Aldrick Robinson
# 1    D.J. Fluker - Tennessee Titans vs. San Diego C...        D.J. Fluker
# 2    Marquise Goodwin - Houston Texans vs. Buffalo ...   Marquise Goodwin
# 3    Bryan Stork - New England Patriots vs. Buffalo...        Bryan Stork
# 4    Lorenzo Booker - Chicago Bears vs. Indianapoli...     Lorenzo Booker
# ..                                                 ...                ...
# 387  Eric Weddle - Baltimore Ravens vs. San Diego C...        Eric Weddle
# 388  Blidi Wreh-Wilson - Indianapolis Colts vs. Ten...  Blidi Wreh-Wilson
# 389  Josh Sitton - Green Bay Packers vs. Tennessee ...        Josh Sitton
# 390  Nate Solder - New England Patriots vs. Clevela...        Nate Solder
# 391  Tony Jefferson - Arizona Cardinals vs. Philade...     Tony Jefferson
#
#                      Team                                               Game  \
# 0     Washington Redskins  Washington Redskins vs. Tampa Bay Buccaneers (...
# 1      San Diego Chargers  Tennessee Titans vs. San Diego Chargers (22/9/...
# 2           Buffalo Bills       Houston Texans vs. Buffalo Bills (28/9/2014)
# 3    New England Patriots  New England Patriots vs. Buffalo Bills (12/10/...
# 4           Chicago Bears    Chicago Bears vs. Indianapolis Colts (9/9/2012)
# ..                    ...                                                ...
# 387    San Diego Chargers  Baltimore Ravens vs. San Diego Chargers (25/11...
# 388      Tennessee Titans  Indianapolis Colts vs. Tennessee Titans (28/9/...
# 389     Green Bay Packers  Green Bay Packers vs. Tennessee Titans (23/12/...
# 390  New England Patriots  New England Patriots vs. Cleveland Browns (8/1...
# 391     Arizona Cardinals  Arizona Cardinals vs. Philadelphia Eagles (26/...
#
#            Date         Opposing Team          Position Pre-Season Injury?  \
# 0    30/09/2012  Tampa Bay Buccaneers     Wide Receiver                 No
# 1    22/09/2013      Tennessee Titans  Offensive Tackle                 No
# 2    28/09/2014        Houston Texans     Wide Receiver                 No
# 3    12/10/2014         Buffalo Bills            Center                 No
# 4     9/09/2012    Indianapolis Colts      Running Back                Yes
# ..          ...                   ...               ...                ...
# 387  25/11/2012      Baltimore Ravens            Safety                 No
# 388  28/09/2014    Indianapolis Colts         Comerback                 No
# 389  23/12/2012      Tennessee Titans             Guard                 No
# 390   8/12/2013      Cleveland Browns  Offensive Tackle                 No
# 391  26/10/2014   Philadelphia Eagles            Safety                 No
#
#     Winning Team?  Week of Injury     Season  Weeks Injured  Games Missed  \
# 0             Yes               4  2012/2013              1           1.0
# 1              No               3  2013/2014              1           1.0
# 2              No               4  2014/2015              1           1.0
# 3             Yes               6  2014/2015              1           1.0
# 4             Yes               1  2012/2013              0           NaN
# ..            ...             ...        ...            ...           ...
# 387            No              12  2012/2013              1           0.0
# 388            No               4  2014/2015              1           1.0
# 389           Yes              16  2012/2013              1           0.0
# 390           Yes              14  2013/2014              1           0.0
# 391           Yes               8  2014/2015              1           0.0
#
#     Unknown Injury? Reported Injury Type  Total Snaps  \
# 0                No                 Head            0
# 1                No           Concussion            0
# 2                No           Concussion            0
# 3                No                 Head            0
# 4                No                 Head            0
# ..              ...                  ...          ...
# 387              No           Concussion           85
# 388              No           Concussion           85
# 389              No           Concussion           87
# 390              No           Concussion           87
# 391              No           Concussion           93
#
#          Play Time After Injury Average Playtime Before Injury
# 0                      14 downs                    37.00 downs
# 1                      78 downs                    73.50 downs
# 2                      25 downs                    17.50 downs
# 3                      82 downs                    41.50 downs
# 4    Did not return from injury                            NaN
# ..                          ...                            ...
# 387                    90 downs                    76.00 downs
# 388                    90 downs                    78.00 downs
# 389                    70 downs                    73.64 downs
# 390                    52 downs                    78.83 downs
# 391                    33 downs                    64.83 downs
#
# [392 rows x 18 columns]

# %% [markdown]
# There are a lot of thing going on here, but two of them are super important and are what makes dataframes different from 2D arrays. One is the column titles, which are all descriptive strings. The next is the index, which is normal right now, but the cool thing about Pandas is that we can change that

# %%
# change the index to the "Date" column
sports_injuries.index = sports_injuries['Date']
display(sports_injuries)
# Out:
#                                                            ID  \
# Date
# 30/09/2012  Aldrick Robinson - Washington Redskins vs. Tam...
# 22/09/2013  D.J. Fluker - Tennessee Titans vs. San Diego C...
# 28/09/2014  Marquise Goodwin - Houston Texans vs. Buffalo ...
# 12/10/2014  Bryan Stork - New England Patriots vs. Buffalo...
# 9/09/2012   Lorenzo Booker - Chicago Bears vs. Indianapoli...
# ...                                                       ...
# 25/11/2012  Eric Weddle - Baltimore Ravens vs. San Diego C...
# 28/09/2014  Blidi Wreh-Wilson - Indianapolis Colts vs. Ten...
# 23/12/2012  Josh Sitton - Green Bay Packers vs. Tennessee ...
# 8/12/2013   Nate Solder - New England Patriots vs. Clevela...
# 26/10/2014  Tony Jefferson - Arizona Cardinals vs. Philade...
#
#                        Player                  Team  \
# Date
# 30/09/2012   Aldrick Robinson   Washington Redskins
# 22/09/2013        D.J. Fluker    San Diego Chargers
# 28/09/2014   Marquise Goodwin         Buffalo Bills
# 12/10/2014        Bryan Stork  New England Patriots
# 9/09/2012      Lorenzo Booker         Chicago Bears
# ...                       ...                   ...
# 25/11/2012        Eric Weddle    San Diego Chargers
# 28/09/2014  Blidi Wreh-Wilson      Tennessee Titans
# 23/12/2012        Josh Sitton     Green Bay Packers
# 8/12/2013         Nate Solder  New England Patriots
# 26/10/2014     Tony Jefferson     Arizona Cardinals
#
#                                                          Game        Date  \
# Date
# 30/09/2012  Washington Redskins vs. Tampa Bay Buccaneers (...  30/09/2012
# 22/09/2013  Tennessee Titans vs. San Diego Chargers (22/9/...  22/09/2013
# 28/09/2014       Houston Texans vs. Buffalo Bills (28/9/2014)  28/09/2014
# 12/10/2014  New England Patriots vs. Buffalo Bills (12/10/...  12/10/2014
# 9/09/2012     Chicago Bears vs. Indianapolis Colts (9/9/2012)   9/09/2012
# ...                                                       ...         ...
# 25/11/2012  Baltimore Ravens vs. San Diego Chargers (25/11...  25/11/2012
# 28/09/2014  Indianapolis Colts vs. Tennessee Titans (28/9/...  28/09/2014
# 23/12/2012  Green Bay Packers vs. Tennessee Titans (23/12/...  23/12/2012
# 8/12/2013   New England Patriots vs. Cleveland Browns (8/1...   8/12/2013
# 26/10/2014  Arizona Cardinals vs. Philadelphia Eagles (26/...  26/10/2014
#
#                    Opposing Team          Position Pre-Season Injury?  \
# Date
# 30/09/2012  Tampa Bay Buccaneers     Wide Receiver                 No
# 22/09/2013      Tennessee Titans  Offensive Tackle                 No
# 28/09/2014        Houston Texans     Wide Receiver                 No
# 12/10/2014         Buffalo Bills            Center                 No
# 9/09/2012     Indianapolis Colts      Running Back                Yes
# ...                          ...               ...                ...
# 25/11/2012      Baltimore Ravens            Safety                 No
# 28/09/2014    Indianapolis Colts         Comerback                 No
# 23/12/2012      Tennessee Titans             Guard                 No
# 8/12/2013       Cleveland Browns  Offensive Tackle                 No
# 26/10/2014   Philadelphia Eagles            Safety                 No
#
#            Winning Team?  Week of Injury     Season  Weeks Injured  \
# Date
# 30/09/2012           Yes               4  2012/2013              1
# 22/09/2013            No               3  2013/2014              1
# 28/09/2014            No               4  2014/2015              1
# 12/10/2014           Yes               6  2014/2015              1
# 9/09/2012            Yes               1  2012/2013              0
# ...                  ...             ...        ...            ...
# 25/11/2012            No              12  2012/2013              1
# 28/09/2014            No               4  2014/2015              1
# 23/12/2012           Yes              16  2012/2013              1
# 8/12/2013            Yes              14  2013/2014              1
# 26/10/2014           Yes               8  2014/2015              1
#
#             Games Missed Unknown Injury? Reported Injury Type  Total Snaps  \
# Date
# 30/09/2012           1.0              No                 Head            0
# 22/09/2013           1.0              No           Concussion            0
# 28/09/2014           1.0              No           Concussion            0
# 12/10/2014           1.0              No                 Head            0
# 9/09/2012            NaN              No                 Head            0
# ...                  ...             ...                  ...          ...
# 25/11/2012           0.0              No           Concussion           85
# 28/09/2014           1.0              No           Concussion           85
# 23/12/2012           0.0              No           Concussion           87
# 8/12/2013            0.0              No           Concussion           87
# 26/10/2014           0.0              No           Concussion           93
#
#                 Play Time After Injury Average Playtime Before Injury
# Date
# 30/09/2012                    14 downs                    37.00 downs
# 22/09/2013                    78 downs                    73.50 downs
# 28/09/2014                    25 downs                    17.50 downs
# 12/10/2014                    82 downs                    41.50 downs
# 9/09/2012   Did not return from injury                            NaN
# ...                                ...                            ...
# 25/11/2012                    90 downs                    76.00 downs
# 28/09/2014                    90 downs                    78.00 downs
# 23/12/2012                    70 downs                    73.64 downs
# 8/12/2013                     52 downs                    78.83 downs
# 26/10/2014                    33 downs                    64.83 downs
#
# [392 rows x 18 columns]

# %% [markdown]
# Yep, we can do that. This is just about the only other way you'll use the index column, and we'll talk more about datetime objects later (especially if you do time series analysis) because you can actually index through them. We wouldn't really want to set the index to anything else besides a datetime or int (even if we can), as this would cause a lot of issues (and make some people very mad).

# %%
# we'll reset to a normal index. 
# This looks complicated but its just integers from 0 (inclusive) to the length of the dataframe (exclusive)
sports_injuries.index = range(len(sports_injuries))

# %% [markdown]
# Now we can get into the useful stuff: searching and sorting. We use df.loc[index, column] to access an entry in the dataframe. If you want just a row you can use df.loc[index] and df[column] for just a column. Indices are usually integers and columns are usually strings.

# %% [markdown]
# Bonus: if for some reason you want to be consistent, you can use df.loc[:, column]. It's the exact same as df[column]. The ":" is just the same as indexing all of the rows, its basically implying 0 : len(df).

# %%
# Let's see what teams are represented in this dataset
sports_injuries['Team']
# Out:
# 0       Washington Redskins
# 1        San Diego Chargers
# 2             Buffalo Bills
# 3      New England Patriots
# 4             Chicago Bears
#                ...
# 387      San Diego Chargers
# 388        Tennessee Titans
# 389       Green Bay Packers
# 390    New England Patriots
# 391       Arizona Cardinals
# Name: Team, Length: 392, dtype: object

# %% [markdown]
# Wow, 391 is a lot. However will we sort through this? Numpy comes to the rescue here with np.unique(). It returns all of the unique values in the column.

# %%
unique_array = np.unique(sports_injuries['Team'])
print(unique_array)
print(f"Length of array: {len(unique_array)}")
# Out:
# ['Arizona Cardinals' 'Atlanta Falcons' 'Baltimore Ravens' 'Buffalo Bills'
#  'Carolina Panthers' 'Chicago Bears' 'Cincinnati Bengals'
#  'Cleveland Browns' 'Dallas Cowboys' 'Denver Broncos' 'Detroit Lions'
#  'Green Bay Packers' 'Houston Texans' 'Indianapolis Colts'
#  'Jacksonville Jaguars' 'Kansas City Chiefs' 'Miami Dolphins'
#  'Minnesota Vikings' 'New England Patriots' 'New Orleans Saints'
#  'New York Giants' 'New York Jets' 'Oakland Raiders' 'Philadelphia Eagles'
#  'Pittsburgh Steelers' 'San Diego Chargers' 'San Francisco 49ers'
#  'Seattle Seahawks' 'St. Louis Rams' 'Tampa Bay Buccaneers'
#  'Tennessee Titans' 'Washington Redskins']
# Length of array: 32

# %% [markdown]
# That's a lot less! Only 32 unique teams are represented in the dataset. We can also find out how often each is represented by returning counts.

# %%
unique_array, team_counts = np.unique(sports_injuries['Team'], return_counts=True)
# If you're wondering how to remember the variables names for function calls like this, 
# they are always camel case and never use caps (very unlike Java)

print(unique_array)
# print statements automatically start a new line (also unlike Java)
print(team_counts)
# Out:
# ['Arizona Cardinals' 'Atlanta Falcons' 'Baltimore Ravens' 'Buffalo Bills'
#  'Carolina Panthers' 'Chicago Bears' 'Cincinnati Bengals'
#  'Cleveland Browns' 'Dallas Cowboys' 'Denver Broncos' 'Detroit Lions'
#  'Green Bay Packers' 'Houston Texans' 'Indianapolis Colts'
#  'Jacksonville Jaguars' 'Kansas City Chiefs' 'Miami Dolphins'
#  'Minnesota Vikings' 'New England Patriots' 'New Orleans Saints'
#  'New York Giants' 'New York Jets' 'Oakland Raiders' 'Philadelphia Eagles'
#  'Pittsburgh Steelers' 'San Diego Chargers' 'San Francisco 49ers'
#  'Seattle Seahawks' 'St. Louis Rams' 'Tampa Bay Buccaneers'
#  'Tennessee Titans' 'Washington Redskins']
# [10  6 15  5  8  9 22 22 10 12 13 13 10 16 21 15  5 13 13 11  9 13 21  9
#  11 12 12 12 12  8 11 13]

# %% [markdown]
# This is a pretty interesting distribution. Well, at least it would be if we could make any sense of it. This isn't the topic for today, but we're gonna use matplotlib for this. Luckily, we don't have to import it right now because pandas has some built-in functions to plot histograms for us.

# %%
# We have to convert from a numpy array to a pandas series so we can use pandas functions (this is important!)
team_counts = pd.Series(team_counts)
team_counts.hist()
# Out:
# <Axes: >

# %% [markdown]
# Now we can get a good look. It seems like there's a few teams with unusually high injuries that skew our distribution right, but otherwise its a pretty normal (get it?) distribution.

# %% [markdown]
# You'll learn later that this is not a great way to make graphs. This histogram is super ugly (and we use box plots for statistical distributions), but it will do for now.
